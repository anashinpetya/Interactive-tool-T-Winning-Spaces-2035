# %%
import pandas as pd
import geopandas as gpd
import numpy as np

# %%
s1_s2_cars_abs=gpd.read_file("s1_s2_cars_difference_rebounds_abs_change.gpkg")

# %%
s1_s2_cars_abs
# Out:
#        num_lines_1  num_lines_2  total_trips_1  total_trips_2  \
# 0               26           26              8             26
# 1              811          811            802            834
# 2              382          382            120            377
# 3                1            1              0              1
# 4               42           42             12             40
# ...            ...          ...            ...            ...
# 40905            4            4              2              4
# 40906            0            0              0              0
# 40907            0            0              0              0
# 40908            0            0              0              0
# 40909            2            2              0              2
#
#        absolute_change  percentage_change  \
# 0                   18           2.250000
# 1                   32           0.039900
# 2                  257           2.141667
# 3                    1                NaN
# ...
